# %%
import re
import random

# %%
patterns={
    r'hi[hello]hey': ["Hello!", "Hi there!", "Hey! How can I help you?"],
    r'how are you': ["Iam fine!", "Doing great!", "I am here to help you."],
    r'what is your name': ["Iam an NLP Chatbot.","You can call me NLP Bot."],
    r'bye[exit]': ["Goodbye!", "See you soon!", "Have a great day!"]
}

# %%
def chatbot_response(user_input):
    user_input=user_input.lower()
    for pattern, responses in patterns.items():
        if re.search(pattern,user_input):
            return random.choice(responses)
    return "Sorry, I did not understand that."

print("Chatbot is running! Type 'bye' to exit.")

while True:
    user=input("You: ")
    response=chatbot_response(user)
    print("Bot:", response)
    if re.search(r'bye|exit', user.lower()):
        break
# Out:
# Chatbot is running! Type 'bye' to exit.
# Bot: Sorry, I did not understand that.
