# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\subik\downloads\practical\.venv\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\subik\downloads\practical\.venv\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in c:\users\subik\downloads\practical\.venv\lib\site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in c:\users\subik\downloads\practical\.venv\lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\subik\downloads\practical\.venv\lib\site-packages (from nltk>=3.9->textblob) (2026.1.15)
# Requirement already satisfied: tqdm in c:\users\subik\downloads\practical\.venv\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\subik\downloads\practical\.venv\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob

# %%
reviews=[
    "I love this product, it is amazing!",
    "This is the worst purchase I ever made.",
    "The product is okay, not great."
]

# %%
for review in reviews:
    blob=TextBlob(review)
    polarity=blob.sentiment.polarity
    if polarity > 0:
        sentiment="Positive"
    elif polarity < 0:
        sentiment="Negative"
    else:
        sentiment="Neutral"
    print(f"Review: {review}\nSentiment: {sentiment}\nPolarity: {polarity}\n")
# Out:
# Review: I love this product, it is amazing!
# Sentiment: Positive
# Polarity: 0.625
#
# Review: This is the worst purchase I ever made.
# Sentiment: Negative
# Polarity: -1.0
#
# Review: The product is okay, not great.
# Sentiment: Positive
# Polarity: 0.04999999999999999
